# %% [markdown]
# ## Grants - Seguridad de Objetos Medallion

# %%
# %sql
-- Otorgar permisos de uso sobre el catálogo
GRANT USE CATALOG ON CATALOG catalog_au TO `ejemplo04@gmail.com`;

# %%
# %sql
-- Otorgar permisos de uso sobre los esquemas
GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `ejemplo04@gmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_au.silver TO `ejemplo04@gmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_au.golden TO `ejemplo04@gmail.com`;

# %%
# %sql
-- Otorgar permisos de lectura sobre las tablas procesadas
GRANT SELECT ON TABLE catalog_au.golden.reporte_calidad_conceptos TO `ejemplo04@gmail.com`;
GRANT SELECT ON TABLE catalog_au.golden.resumen_prioridad_dominio TO `ejemplo04@gmail.com`;
GRANT SELECT ON TABLE catalog_au.silver.conceptos_calidad_trazabilidad TO `ejemplo04@gmail.com`;

# %%
# %sql
-- Otorgar permisos sobre la tabla de adiciones de la App
GRANT SELECT, MODIFY ON TABLE catalog_au.bronze.app_custom_concepts TO `ejemplo04@gmail.com`;
